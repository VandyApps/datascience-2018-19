# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('athlete_events.csv')

# %%
data.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
data['Year'].unique()
# Out:
# array([1992, 2012, 1920, 1900, 1988, 1994, 1932, 2002, 1952, 1980, 2000,
#        1996, 1912, 1924, 2014, 1948, 1998, 2006, 2008, 2016, 2004, 1960,
#        1964, 1984, 1968, 1972, 1936, 1956, 1928, 1976, 2010, 1906, 1904,
#        1908, 1896], dtype=int64)

# %%
events2012 = data[data['Year']==2012]

# %%
target = events2012[events2012['Medal']=='Gold']

# %%
data.shape
# Out:
# (271116, 15)

# %%
target.shape
# Out:
# (632, 15)

# %%
target.head(1)
# Out:
#      ID       Name Sex   Age  Height  Weight    Team  NOC        Games  Year  \
# 174  73  Luc Abalo   M  27.0   182.0    86.0  France  FRA  2012 Summer  2012
#
#      Season    City     Sport                    Event Medal
# 174  Summer  London  Handball  Handball Men's Handball  Gold

# %%
target.groupby('Team').count()
# Out:
#                       ID  Name  Sex  Age  Height  Weight  NOC  Games  Year  \
# Team
# Algeria                1     1    1    1       1       1    1      1     1
# Argentina              1     1    1    1       1       1    1      1     1
# Australia             18    18   18   18      18      18   18     18    18
# Azerbaijan             2     2    2    2       2       2    2      2     2
# Bahamas                4     4    4    4       4       4    4      4     4
# Belarus                3     3    3    3       3       3    3      3     3
# Brazil                14    14   14   14      14      14   14     14    14
# Canada                 1     1    1    1       1       1    1      1     1
# China                 50    50   50   50      50      50   50     50    50
# China-1                6     6    6    6       6       6    6      6     6
# Colombia               1     1    1    1       1       1    1      1     1
# ...

# %%
target.groupby('Team').count()['ID'].values
# Out:
# array([  1,   1,  18,   2,   4,   3,  14,   1,  50,   6,   1,  15,   5,
#          4,   3,   1,   3,  30,   1,  43,   2,  46,   2,   1,  12,   4,
#          1,  16,   8,   7,   7,   2,   1,   2,  16,  21,   9,   4,  15,
#          2,   2,  50,   1,   1,   6,  18,   5,   2,   2,   1,   1,   2,
#          1,   9, 139,   6,   1,   1], dtype=int64)

# %%
range(len(target['Team']))
# Out:
# range(0, 632)

# %%
target.groupby('Team').count().index
# Out:
# Index(['Algeria', 'Argentina', 'Australia', 'Azerbaijan', 'Bahamas', 'Belarus',
#        'Brazil', 'Canada', 'China', 'China-1', 'Colombia', 'Croatia', 'Cuba',
#        'Czech Republic', 'Denmark', 'Dominican Republic', 'Ethiopia', 'France',
#        'Georgia', 'Germany', 'Germany-1', 'Great Britain', 'Great Britain-1',
#        'Grenada', 'Hungary', 'Iran', 'Ireland', 'Italy', 'Jamaica', 'Japan',
#        'Kazakhstan', 'Kenya', 'Latvia', 'Lithuania', 'Mexico', 'Netherlands',
#        'New Zealand', 'North Korea', 'Norway', 'Poland', 'Romania', 'Russia',
#        'Serbia', 'Slovenia', 'South Africa', 'South Korea', 'Spain', 'Sweden',
#        'Switzerland', 'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Uganda',
#        'Ukraine', 'United States', 'United States-1', 'Uzbekistan',
#        'Venezuela'],
#       dtype='object', name='Team')

# %%
ax = plt.bar(range(len(target['Team'].unique())), target.groupby('Team').count()['ID'].values)
#plt.set_xticklabels(target.groupby('Team').count().index)

# %%
# time series plot of usa gold medals

target = data[(data['Team']=='United States') & (data['Medal']=='Gold') ]

# %%
plt.figure(figsize=(10,5))
plt.plot(target.groupby('Year').count()['Medal'])

# %%
plt.scatter(target['Year'].unique(), target.groupby('Year').count()['Medal'])

# %% [markdown]
# # TSNE t-stochastic neighbors embedding
#
# Dimensionality reduction techniques:
# - PCA
# - TSNE
# - MDS
#
# Cool Demos:
# https://dash-gallery.plotly.host/dash-tsne/
